# %%
#!pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('whitegrid')
titanic = sns.load_dataset('titanic') #loading the dataset
sns.jointplot(x='fare',y='age',data=titanic) #creating the seaborn plot
